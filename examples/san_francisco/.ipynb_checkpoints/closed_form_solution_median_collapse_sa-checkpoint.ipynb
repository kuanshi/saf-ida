# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
ims = []
rps = [224,475,975,2475,4975,9950]
for rp in rps:
    ims.append(pd.read_csv('SanFrancisco_RP{}.csv'.format(rp),header=0,index_col=False))

# %%
T1 = 1.12
Ta = int(0.2*T1*100)/100
Tb = int(3*T1*100)/100

# %%
sa = []
saratio = []
for i,rp in enumerate(rps):
    sa.append(ims[i].iloc[:,int(T1*100)].to_numpy()[0])
    saratio.append(ims[i].iloc[:,int(T1*100)].to_numpy()/np.exp(np.mean(np.log(ims[i].iloc[:,int(Ta*100):int(Tb*100)].to_numpy()),axis=1)))

# %%
m_saratio = np.exp(np.mean(np.log(saratio),axis=1))

# %%
model = LinearRegression()
model.fit(np.log(m_saratio).reshape(-1, 1) ,np.log(sa))
print('intercept a0 = {}'.format(model.intercept_))
print('slope a1 = {}'.format(model.coef_))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 2
#       1 model = LinearRegression()
# ----> 2 model.fit(np.log(m_saratio),np.log(sa))
#       3 print('intercept a0 = {}'.format(model.intercept_))
#       4 print('slope a1 = {}'.format(model.coef_))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_base.py:601, in LinearRegression.fit(self, X, y, sample_weight)
# ...

# %%
np.log(m_saratio)
# Out:
# array([0.39693446, 0.40716242, 0.42163417, 0.44659638, 0.47104294,
#        0.4931519 ])

# %%
np.log(sa)
# Out:
# array([-0.81947658, -0.46872171, -0.19686368,  0.10744405,  0.31714741,
#         0.508382  ])
